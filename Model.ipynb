# %%
import numpy as np
import cv2
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.layers import Conv2D, Flatten, MaxPooling2D,Dense,Dropout,SpatialDropout2D
from keras.models  import Sequential
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img, array_to_img
import random,os,glob
import matplotlib.pyplot as plt

# %%
import zipfile
from google.colab import drive



zip_ref = zipfile.ZipFile("dataset-resized.zip", 'r')
zip_ref.extractall("data")
zip_ref.close()

# %%
dir_path = 'data/dataset-resized'

# %%
img_list = glob.glob(os.path.join(dir_path, '*/*.jpg'))

# %%
len(img_list)
# Out:
# 2527

# %%
train=ImageDataGenerator(horizontal_flip=True,
                         vertical_flip=True,
                         validation_split=0.1,
                         rescale=1./255,
                         shear_range = 0.1,
                         zoom_range = 0.1,
                         width_shift_range = 0.1,
                         height_shift_range = 0.1,)

test=ImageDataGenerator(rescale=1/255,
                        validation_split=0.1)

train_generator=train.flow_from_directory(dir_path,
                                          target_size=(300,300),
                                          batch_size=32,
                                          class_mode='categorical',
                                          subset='training')

test_generator=test.flow_from_directory(dir_path,
                                        target_size=(300,300),
                                        batch_size=32,
                                        class_mode='categorical',
                                        subset='validation')

labels = (train_generator.class_indices)
print(labels)

labels = dict((v,k) for k,v in labels.items())
print(labels)
# Out:
# Found 2276 images belonging to 6 classes.
# Found 251 images belonging to 6 classes.
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %%
for image_batch, label_batch in train_generator:
  break
image_batch.shape, label_batch.shape
# Out:
# ((32, 300, 300, 3), (32, 6))

# %%
print (train_generator.class_indices)

Labels = '\n'.join(sorted(train_generator.class_indices.keys()))

with open('labels.txt', 'w') as f:
  f.write(Labels)
# Out:
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}

# %%
model=Sequential()
#Convolution blocks

model.add(Conv2D(32,(3,3), padding='same',input_shape=(300,300,3),activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 
#model.add(SpatialDropout2D(0.5)) # No accuracy

model.add(Conv2D(64,(3,3), padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 
#model.add(SpatialDropout2D(0.5))

model.add(Conv2D(32,(3,3), padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 

#Classification layers
model.add(Flatten())

model.add(Dense(64,activation='relu'))
#model.add(SpatialDropout2D(0.5))
model.add(Dropout(0.2))
model.add(Dense(32,activation='relu'))

model.add(Dropout(0.2))
model.add(Dense(6,activation='softmax'))

filepath="trained_model.h5"
checkpoint1 = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint1]

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc']) # RMS PROP - No accuracy

# %%
history = model.fit_generator(train_generator,
                              epochs=100,
                              steps_per_epoch=2276//32,
                              validation_data=test_generator,
                              validation_steps=251//32,
                              workers = 4,
                              callbacks=callbacks_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 71/71 [==============================] - 334s 5s/step - loss: 1.7800 - acc: 0.1956 - val_loss: 1.6948 - val_acc: 0.2857
#
# Epoch 00001: val_acc improved from -inf to 0.28571, saving model to trained_model.h5
# Epoch 2/100
# 71/71 [==============================] - 332s 5s/step - loss: 1.6516 - acc: 0.2619 - val_loss: 1.5844 - val_acc: 0.3795
#
# Epoch 00002: val_acc improved from 0.28571 to 0.37946, saving model to trained_model.h5
# Epoch 3/100
# 71/71 [==============================] - 332s 5s/step - loss: 1.5778 - acc: 0.3327 - val_loss: 1.5278 - val_acc: 0.3884
#
# Epoch 00003: val_acc improved from 0.37946 to 0.38839, saving model to trained_model.h5
# Epoch 4/100
# 71/71 [==============================] - 332s 5s/step - loss: 1.5393 - acc: 0.3613 - val_loss: 1.4853 - val_acc: 0.4241
#
# Epoch 00004: val_acc improved from 0.38839 to 0.42411, saving model to trained_model.h5
# Epoch 5/100
# 71/71 [==============================] - 331s 5s/step - loss: 1.4676 - acc: 0.3858 - val_loss: 1.4266 - val_acc: 0.4420
#
# Epoch 00005: val_acc improved from 0.42411 to 0.44196, saving model to trained_model.h5
# Epoch 6/100
# 71/71 [==============================] - 330s 5s/step - loss: 1.4306 - acc: 0.4206 - val_loss: 1.3570 - val_acc: 0.4330
#
# Epoch 00006: val_acc did not improve from 0.44196
# Epoch 7/100
# 71/71 [==============================] - 330s 5s/step - loss: 1.4332 - acc: 0.3970 - val_loss: 1.3803 - val_acc: 0.4420
#
# Epoch 00007: val_acc did not improve from 0.44196
# Epoch 8/100
# 71/71 [==============================] - 330s 5s/step - loss: 1.4039 - acc: 0.4222 - val_loss: 1.2755 - val_acc: 0.4643
#
# Epoch 00008: val_acc improved from 0.44196 to 0.46429, saving model to trained_model.h5
# Epoch 9/100
# 71/71 [==============================] - 329s 5s/step - loss: 1.3853 - acc: 0.4384 - val_loss: 1.2606 - val_acc: 0.4777
#
# Epoch 00009: val_acc improved from 0.46429 to 0.47768, saving model to trained_model.h5
# Epoch 10/100
# 71/71 [==============================] - 330s 5s/step - loss: 1.3189 - acc: 0.4617 - val_loss: 1.2854 - val_acc: 0.4866
#
# Epoch 00010: val_acc improved from 0.47768 to 0.48661, saving model to trained_model.h5
# Epoch 11/100
# 71/71 [==============================] - 329s 5s/step - loss: 1.3973 - acc: 0.4556 - val_loss: 1.2826 - val_acc: 0.4732
#
# Epoch 00011: val_acc did not improve from 0.48661
# Epoch 12/100
# 71/71 [==============================] - 330s 5s/step - loss: 1.2960 - acc: 0.4904 - val_loss: 1.3257 - val_acc: 0.4598
#
# Epoch 00012: val_acc did not improve from 0.48661
# Epoch 13/100
# 71/71 [==============================] - 329s 5s/step - loss: 1.3169 - acc: 0.4909 - val_loss: 1.3635 - val_acc: 0.4107
#
# Epoch 00013: val_acc did not improve from 0.48661
# Epoch 14/100
# 71/71 [==============================] - 328s 5s/step - loss: 1.2656 - acc: 0.4947 - val_loss: 1.2051 - val_acc: 0.4911
#
# Epoch 00014: val_acc improved from 0.48661 to 0.49107, saving model to trained_model.h5
# Epoch 15/100
# 71/71 [==============================] - 328s 5s/step - loss: 1.2625 - acc: 0.5082 - val_loss: 1.2446 - val_acc: 0.4643
#
# Epoch 00015: val_acc did not improve from 0.49107
# Epoch 16/100
# 71/71 [==============================] - 329s 5s/step - loss: 1.2832 - acc: 0.5080 - val_loss: 1.2133 - val_acc: 0.5045
#
# Epoch 00016: val_acc improved from 0.49107 to 0.50446, saving model to trained_model.h5
# Epoch 17/100
# 71/71 [==============================] - 327s 5s/step - loss: 1.2839 - acc: 0.4821 - val_loss: 1.2436 - val_acc: 0.4688
#
# Epoch 00017: val_acc did not improve from 0.50446
# Epoch 18/100
# 71/71 [==============================] - 326s 4s/step - loss: 1.2320 - acc: 0.5196 - val_loss: 1.1973 - val_acc: 0.4911
#
# Epoch 00018: val_acc did not improve from 0.50446
# Epoch 19/100
# 71/71 [==============================] - 326s 4s/step - loss: 1.2136 - acc: 0.5181 - val_loss: 1.2585 - val_acc: 0.4866
#
# Epoch 00019: val_acc did not improve from 0.50446
# Epoch 20/100
# 71/71 [==============================] - 326s 4s/step - loss: 1.2305 - acc: 0.5223 - val_loss: 1.1637 - val_acc: 0.5402
#
# Epoch 00020: val_acc improved from 0.50446 to 0.54018, saving model to trained_model.h5
# Epoch 21/100
# 71/71 [==============================] - 326s 4s/step - loss: 1.1516 - acc: 0.5667 - val_loss: 1.1815 - val_acc: 0.5402
#
# Epoch 00021: val_acc did not improve from 0.54018
# Epoch 22/100
# 71/71 [==============================] - 327s 5s/step - loss: 1.1593 - acc: 0.5479 - val_loss: 1.0524 - val_acc: 0.6339
#
# Epoch 00022: val_acc improved from 0.54018 to 0.63393, saving model to trained_model.h5
# Epoch 23/100
# 71/71 [==============================] - 326s 4s/step - loss: 1.1137 - acc: 0.5649 - val_loss: 1.0983 - val_acc: 0.5714
#
# Epoch 00023: val_acc did not improve from 0.63393
# Epoch 24/100
# 71/71 [==============================] - 327s 5s/step - loss: 1.0955 - acc: 0.5944 - val_loss: 1.0966 - val_acc: 0.5536
#
# Epoch 00024: val_acc did not improve from 0.63393
# Epoch 25/100
# 71/71 [==============================] - 326s 5s/step - loss: 1.0908 - acc: 0.5807 - val_loss: 1.0619 - val_acc: 0.6116
#
# Epoch 00025: val_acc did not improve from 0.63393
# Epoch 26/100
# 71/71 [==============================] - 327s 5s/step - loss: 1.0131 - acc: 0.6319 - val_loss: 1.0205 - val_acc: 0.5982
#
# Epoch 00026: val_acc did not improve from 0.63393
# Epoch 27/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.9899 - acc: 0.6201 - val_loss: 0.9483 - val_acc: 0.6652
#
# Epoch 00027: val_acc improved from 0.63393 to 0.66518, saving model to trained_model.h5
# Epoch 28/100
# 71/71 [==============================] - 329s 5s/step - loss: 1.0205 - acc: 0.6352 - val_loss: 0.9599 - val_acc: 0.6250
#
# Epoch 00028: val_acc did not improve from 0.66518
# Epoch 29/100
# 71/71 [==============================] - 329s 5s/step - loss: 0.9692 - acc: 0.6248 - val_loss: 0.9178 - val_acc: 0.6607
#
# Epoch 00029: val_acc did not improve from 0.66518
# Epoch 30/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.9876 - acc: 0.6371 - val_loss: 1.0233 - val_acc: 0.6339
#
# Epoch 00030: val_acc did not improve from 0.66518
# Epoch 31/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.9116 - acc: 0.6733 - val_loss: 0.8914 - val_acc: 0.6607
#
# Epoch 00031: val_acc did not improve from 0.66518
# Epoch 32/100
# 71/71 [==============================] - 329s 5s/step - loss: 0.9164 - acc: 0.6736 - val_loss: 1.0444 - val_acc: 0.6473
#
# Epoch 00032: val_acc did not improve from 0.66518
# Epoch 33/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.9553 - acc: 0.6624 - val_loss: 0.9706 - val_acc: 0.6384
#
# Epoch 00033: val_acc did not improve from 0.66518
# Epoch 34/100
# 71/71 [==============================] - 329s 5s/step - loss: 0.8542 - acc: 0.6938 - val_loss: 0.9064 - val_acc: 0.6741
#
# Epoch 00034: val_acc improved from 0.66518 to 0.67411, saving model to trained_model.h5
# Epoch 35/100
# 71/71 [==============================] - 330s 5s/step - loss: 0.8877 - acc: 0.6754 - val_loss: 0.9164 - val_acc: 0.6562
#
# Epoch 00035: val_acc did not improve from 0.67411
# Epoch 36/100
# 71/71 [==============================] - 329s 5s/step - loss: 0.9187 - acc: 0.6779 - val_loss: 0.9436 - val_acc: 0.6652
#
# Epoch 00036: val_acc did not improve from 0.67411
# Epoch 37/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.8910 - acc: 0.6710 - val_loss: 0.9041 - val_acc: 0.6830
#
# Epoch 00037: val_acc improved from 0.67411 to 0.68304, saving model to trained_model.h5
# Epoch 38/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.8417 - acc: 0.6909 - val_loss: 0.8238 - val_acc: 0.6786
#
# Epoch 00038: val_acc did not improve from 0.68304
# Epoch 39/100
# 71/71 [==============================] - 329s 5s/step - loss: 0.8350 - acc: 0.6874 - val_loss: 0.8625 - val_acc: 0.6607
#
# Epoch 00039: val_acc did not improve from 0.68304
# Epoch 40/100
# 71/71 [==============================] - 329s 5s/step - loss: 0.8531 - acc: 0.6889 - val_loss: 0.8263 - val_acc: 0.7143
#
# Epoch 00040: val_acc improved from 0.68304 to 0.71429, saving model to trained_model.h5
# Epoch 41/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.7987 - acc: 0.7242 - val_loss: 0.8384 - val_acc: 0.7054
#
# Epoch 00041: val_acc did not improve from 0.71429
# Epoch 42/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.8106 - acc: 0.7156 - val_loss: 0.7774 - val_acc: 0.6920
#
# Epoch 00042: val_acc did not improve from 0.71429
# Epoch 43/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.7907 - acc: 0.7134 - val_loss: 0.7642 - val_acc: 0.7366
#
# Epoch 00043: val_acc improved from 0.71429 to 0.73661, saving model to trained_model.h5
# Epoch 44/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.7518 - acc: 0.7294 - val_loss: 0.9040 - val_acc: 0.6875
#
# Epoch 00044: val_acc did not improve from 0.73661
# Epoch 45/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.7736 - acc: 0.7141 - val_loss: 0.8394 - val_acc: 0.6830
#
# Epoch 00045: val_acc did not improve from 0.73661
# Epoch 46/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.7665 - acc: 0.7307 - val_loss: 0.8834 - val_acc: 0.6920
#
# Epoch 00046: val_acc did not improve from 0.73661
# Epoch 47/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.7414 - acc: 0.7405 - val_loss: 0.7937 - val_acc: 0.6964
#
# Epoch 00047: val_acc did not improve from 0.73661
# Epoch 48/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.7952 - acc: 0.7197 - val_loss: 0.8654 - val_acc: 0.6920
#
# Epoch 00048: val_acc did not improve from 0.73661
# Epoch 49/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.7215 - acc: 0.7361 - val_loss: 0.7399 - val_acc: 0.7411
#
# Epoch 00049: val_acc improved from 0.73661 to 0.74107, saving model to trained_model.h5
# Epoch 50/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.7034 - acc: 0.7427 - val_loss: 0.7485 - val_acc: 0.7411
#
# Epoch 00050: val_acc did not improve from 0.74107
# Epoch 51/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.7325 - acc: 0.7292 - val_loss: 0.8337 - val_acc: 0.7366
#
# Epoch 00051: val_acc did not improve from 0.74107
# Epoch 52/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.7227 - acc: 0.7408 - val_loss: 0.8738 - val_acc: 0.6964
#
# Epoch 00052: val_acc did not improve from 0.74107
# Epoch 53/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.7496 - acc: 0.7375 - val_loss: 0.9087 - val_acc: 0.6741
#
# Epoch 00053: val_acc did not improve from 0.74107
# Epoch 54/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.7509 - acc: 0.7401 - val_loss: 0.8372 - val_acc: 0.7009
#
# Epoch 00054: val_acc did not improve from 0.74107
# Epoch 55/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.6679 - acc: 0.7677 - val_loss: 0.8161 - val_acc: 0.7009
#
# Epoch 00055: val_acc did not improve from 0.74107
# Epoch 56/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.7233 - acc: 0.7360 - val_loss: 0.8184 - val_acc: 0.6964
#
# Epoch 00056: val_acc did not improve from 0.74107
# Epoch 57/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.6625 - acc: 0.7662 - val_loss: 0.7756 - val_acc: 0.7054
#
# Epoch 00057: val_acc did not improve from 0.74107
# Epoch 58/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.7481 - acc: 0.7133 - val_loss: 0.7756 - val_acc: 0.7188
#
# Epoch 00058: val_acc did not improve from 0.74107
# Epoch 59/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.6516 - acc: 0.7814 - val_loss: 0.7776 - val_acc: 0.7054
#
# Epoch 00059: val_acc did not improve from 0.74107
# Epoch 60/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.6777 - acc: 0.7610 - val_loss: 0.7667 - val_acc: 0.7455
#
# Epoch 00060: val_acc improved from 0.74107 to 0.74554, saving model to trained_model.h5
# Epoch 61/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.6758 - acc: 0.7585 - val_loss: 0.7497 - val_acc: 0.7321
#
# Epoch 00061: val_acc did not improve from 0.74554
# Epoch 62/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.6743 - acc: 0.7593 - val_loss: 0.7633 - val_acc: 0.7054
#
# Epoch 00062: val_acc did not improve from 0.74554
# Epoch 63/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.6590 - acc: 0.7686 - val_loss: 0.7117 - val_acc: 0.7366
#
# Epoch 00063: val_acc did not improve from 0.74554
# Epoch 64/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.6066 - acc: 0.7901 - val_loss: 0.8426 - val_acc: 0.6964
#
# Epoch 00064: val_acc did not improve from 0.74554
# Epoch 65/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.6527 - acc: 0.7680 - val_loss: 0.8802 - val_acc: 0.6830
#
# Epoch 00065: val_acc did not improve from 0.74554
# Epoch 66/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.6529 - acc: 0.7626 - val_loss: 0.7307 - val_acc: 0.7366
#
# Epoch 00066: val_acc did not improve from 0.74554
# Epoch 67/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.6042 - acc: 0.7820 - val_loss: 0.7553 - val_acc: 0.7277
#
# Epoch 00067: val_acc did not improve from 0.74554
# Epoch 68/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5994 - acc: 0.7817 - val_loss: 0.7866 - val_acc: 0.7098
#
# Epoch 00068: val_acc did not improve from 0.74554
# Epoch 69/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.6028 - acc: 0.7813 - val_loss: 0.7988 - val_acc: 0.7455
#
# Epoch 00069: val_acc did not improve from 0.74554
# Epoch 70/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5838 - acc: 0.7893 - val_loss: 0.8240 - val_acc: 0.7321
#
# Epoch 00070: val_acc did not improve from 0.74554
# Epoch 71/100
# 71/71 [==============================] - 329s 5s/step - loss: 0.6101 - acc: 0.7856 - val_loss: 0.7479 - val_acc: 0.7411
#
# Epoch 00071: val_acc did not improve from 0.74554
# Epoch 72/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5898 - acc: 0.7893 - val_loss: 0.6951 - val_acc: 0.7455
#
# Epoch 00072: val_acc did not improve from 0.74554
# Epoch 73/100
# 71/71 [==============================] - 329s 5s/step - loss: 0.6041 - acc: 0.7800 - val_loss: 0.7849 - val_acc: 0.7455
#
# Epoch 00073: val_acc did not improve from 0.74554
# Epoch 74/100
# 71/71 [==============================] - 329s 5s/step - loss: 0.5680 - acc: 0.7921 - val_loss: 0.8090 - val_acc: 0.6964
#
# Epoch 00074: val_acc did not improve from 0.74554
# Epoch 75/100
# 71/71 [==============================] - 329s 5s/step - loss: 0.6240 - acc: 0.7878 - val_loss: 0.8019 - val_acc: 0.7545
#
# Epoch 00075: val_acc improved from 0.74554 to 0.75446, saving model to trained_model.h5
# Epoch 76/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5675 - acc: 0.7937 - val_loss: 0.7207 - val_acc: 0.7455
#
# Epoch 00076: val_acc did not improve from 0.75446
# Epoch 77/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5702 - acc: 0.8057 - val_loss: 0.7193 - val_acc: 0.7946
#
# Epoch 00077: val_acc improved from 0.75446 to 0.79464, saving model to trained_model.h5
# Epoch 78/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5480 - acc: 0.7996 - val_loss: 0.7371 - val_acc: 0.7188
#
# Epoch 00078: val_acc did not improve from 0.79464
# Epoch 79/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.5940 - acc: 0.7917 - val_loss: 0.7499 - val_acc: 0.7455
#
# Epoch 00079: val_acc did not improve from 0.79464
# Epoch 80/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5640 - acc: 0.7986 - val_loss: 0.7140 - val_acc: 0.7634
#
# Epoch 00080: val_acc did not improve from 0.79464
# Epoch 81/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5082 - acc: 0.8093 - val_loss: 0.6849 - val_acc: 0.7991
#
# Epoch 00081: val_acc improved from 0.79464 to 0.79911, saving model to trained_model.h5
# Epoch 82/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5655 - acc: 0.7956 - val_loss: 0.7335 - val_acc: 0.7500
#
# Epoch 00082: val_acc did not improve from 0.79911
# Epoch 83/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5513 - acc: 0.8032 - val_loss: 0.6879 - val_acc: 0.7679
#
# Epoch 00083: val_acc did not improve from 0.79911
# Epoch 84/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.5259 - acc: 0.8265 - val_loss: 0.7839 - val_acc: 0.7411
#
# Epoch 00084: val_acc did not improve from 0.79911
# Epoch 85/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5153 - acc: 0.8205 - val_loss: 0.7674 - val_acc: 0.7411
#
# Epoch 00085: val_acc did not improve from 0.79911
# Epoch 86/100
# 71/71 [==============================] - 329s 5s/step - loss: 0.5592 - acc: 0.8022 - val_loss: 0.8211 - val_acc: 0.7277
#
# Epoch 00086: val_acc did not improve from 0.79911
# Epoch 87/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5394 - acc: 0.8133 - val_loss: 0.6320 - val_acc: 0.7812
#
# Epoch 00087: val_acc did not improve from 0.79911
# Epoch 88/100
# 71/71 [==============================] - 329s 5s/step - loss: 0.5901 - acc: 0.7868 - val_loss: 0.6385 - val_acc: 0.7946
#
# Epoch 00088: val_acc did not improve from 0.79911
# Epoch 89/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5660 - acc: 0.8029 - val_loss: 0.7048 - val_acc: 0.7545
#
# Epoch 00089: val_acc did not improve from 0.79911
# Epoch 90/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.5211 - acc: 0.8297 - val_loss: 0.8161 - val_acc: 0.6875
#
# Epoch 00090: val_acc did not improve from 0.79911
# Epoch 91/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.5337 - acc: 0.8039 - val_loss: 0.7690 - val_acc: 0.7277
#
# Epoch 00091: val_acc did not improve from 0.79911
# Epoch 92/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.5364 - acc: 0.8082 - val_loss: 0.8007 - val_acc: 0.7589
#
# Epoch 00092: val_acc did not improve from 0.79911
# Epoch 93/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.4932 - acc: 0.8159 - val_loss: 0.7704 - val_acc: 0.7634
#
# Epoch 00093: val_acc did not improve from 0.79911
# Epoch 94/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5240 - acc: 0.8127 - val_loss: 0.7473 - val_acc: 0.7188
#
# Epoch 00094: val_acc did not improve from 0.79911
# Epoch 95/100
# 71/71 [==============================] - 329s 5s/step - loss: 0.5058 - acc: 0.8157 - val_loss: 0.7379 - val_acc: 0.7723
#
# Epoch 00095: val_acc did not improve from 0.79911
# Epoch 96/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.5168 - acc: 0.8126 - val_loss: 0.7430 - val_acc: 0.7500
#
# Epoch 00096: val_acc did not improve from 0.79911
# Epoch 97/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.5516 - acc: 0.8159 - val_loss: 0.8422 - val_acc: 0.7500
#
# Epoch 00097: val_acc did not improve from 0.79911
# Epoch 98/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.4948 - acc: 0.8252 - val_loss: 0.6772 - val_acc: 0.7679
#
# Epoch 00098: val_acc did not improve from 0.79911
# Epoch 99/100
# 71/71 [==============================] - 328s 5s/step - loss: 0.5304 - acc: 0.8070 - val_loss: 0.7243 - val_acc: 0.7723
#
# Epoch 00099: val_acc did not improve from 0.79911
# Epoch 100/100
# 71/71 [==============================] - 327s 5s/step - loss: 0.4488 - acc: 0.8480 - val_loss: 0.8749 - val_acc: 0.7500
#
# Epoch 00100: val_acc did not improve from 0.79911

# %%
from keras.preprocessing import image

img_path = 'bottle.jpg'

img = image.load_img(img_path, target_size=(300, 300))
img = image.img_to_array(img, dtype=np.uint8)
img=np.array(img)/255.0

plt.title("Loaded Image")
plt.axis('off')
plt.imshow(img.squeeze())

p=model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Maximum Probability: ",np.max(p[0], axis=-1))
predicted_class = labels[np.argmax(p[0], axis=-1)]
print("Classified:",predicted_class)
# Out:
# Maximum Probability:  0.9797611
# Classified: paper

# %%
from keras.preprocessing import image

img_path = 'data/dataset-resized/plastic/plastic75.jpg'

img = image.load_img(img_path, target_size=(300, 300))
img = image.img_to_array(img, dtype=np.uint8)
img=np.array(img)/255.0

plt.title("Loaded Image")
plt.axis('off')
plt.imshow(img.squeeze())

p=model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Maximum Probability: ",np.max(p[0], axis=-1))
predicted_class = labels[np.argmax(p[0], axis=-1)]
print("Classified:",predicted_class)
# Out:
# Maximum Probability:  0.9997266
# Classified: plastic

# %%
classes=[]
prob=[]
print("\n-------------------Individual Probability--------------------------------\n")

for i,j in enumerate (p[0],0):
    print(labels[i].upper(),':',round(j*100,2),'%')
    classes.append(labels[i])
    prob.append(round(j*100,2))
    
def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(classes))
    plt.bar(index, prob)
    plt.xlabel('Labels', fontsize=12)
    plt.ylabel('Probability', fontsize=12)
    plt.xticks(index, classes, fontsize=12, rotation=20)
    plt.title('Probability for loaded image')
    plt.show()
plot_bar_x()
# Out:
# -------------------Individual Probability--------------------------------
#
# CARDBOARD : 0.0 %
# GLASS : 0.03 %
# METAL : 0.0 %
# PAPER : 0.0 %
# PLASTIC : 99.97 %
# TRASH : 0.0 %

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

# ________________ Graph 1 -------------------------

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

# ________________ Graph 2 -------------------------

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,max(plt.ylim())])
plt.title('Training and Validation Loss')
plt.show()

# %%
import tensorflow as tf

model = tf.keras.models.load_model( 'Garbage.h5' )

converter = tf.lite.TFLiteConverter.from_keras_model( model )
tflite_model = converter.convert()
open("garbage.tflite", "wb").write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpnf3cjrl8/assets
# 11379808
